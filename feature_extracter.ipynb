# %%
from __future__ import division

import torch 
import torch.nn as nn
import torch.nn.functional as F 
import numpy as np
import time
import cv2 
import argparse
import os 
import os.path as osp
import pickle as pkl
import pandas as pd
import random
import torchvision.models as models
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import skimage
import pickle
#import bcolz
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def parse_cfg(cfgfile):
    """
    Takes a configuration file
    
    Returns a list of blocks. Each blocks describes a block in the neural
    network to be built. Block is represented as a dictionary in the list
    
    """
    
    file = open(cfgfile, 'r')
    lines = file.read().split('\n')                        # store the lines in a list
    lines = [x for x in lines if len(x) > 0]               # get read of the empty lines 
    lines = [x for x in lines if x[0] != '#']              # get rid of comments
    lines = [x.rstrip().lstrip() for x in lines]           # get rid of fringe whitespaces
    
    block = {}
    blocks = []
    
    for line in lines:
        if line[0] == "[":               # This marks the start of a new block
            if len(block) != 0:          # If block is not empty, implies it is storing values of previous block.
                blocks.append(block)     # add it the blocks list
                block = {}               # re-init the block
            block["type"] = line[1:-1].rstrip()     
        else:
            key,value = line.split("=") 
            block[key.rstrip()] = value.lstrip()
    blocks.append(block)
    
    return blocks

# %%
def predict_transform(prediction, inp_dim, anchors, num_classes, CUDA = False):

    
    batch_size = prediction.size(0)
    stride =  inp_dim // prediction.size(2)
    grid_size = inp_dim // stride
    bbox_attrs = 5 + num_classes
    num_anchors = len(anchors)
    
    prediction = prediction.view(batch_size, bbox_attrs*num_anchors, grid_size*grid_size)
    prediction = prediction.transpose(1,2).contiguous()
    prediction = prediction.view(batch_size, grid_size*grid_size*num_anchors, bbox_attrs)
    anchors = [(a[0]/stride, a[1]/stride) for a in anchors]

    #Sigmoid the  centre_X, centre_Y. and object confidencce
    prediction[:,:,0] = torch.sigmoid(prediction[:,:,0])
    prediction[:,:,1] = torch.sigmoid(prediction[:,:,1])
    prediction[:,:,4] = torch.sigmoid(prediction[:,:,4])
    
    #Add the center offsets
    grid = np.arange(grid_size)
    a,b = np.meshgrid(grid, grid)

    x_offset = torch.FloatTensor(a).view(-1,1)
    y_offset = torch.FloatTensor(b).view(-1,1)

    if CUDA:
        x_offset = x_offset.cuda()
        y_offset = y_offset.cuda()

    x_y_offset = torch.cat((x_offset, y_offset), 1).repeat(1,num_anchors).view(-1,2).unsqueeze(0)

    prediction[:,:,:2] += x_y_offset

    #log space transform height and the width
    anchors = torch.FloatTensor(anchors)

    if CUDA:
        anchors = anchors.cuda()

    anchors = anchors.repeat(grid_size*grid_size, 1).unsqueeze(0)
    prediction[:,:,2:4] = torch.exp(prediction[:,:,2:4])*anchors
    
    prediction[:,:,5: 5 + num_classes] = torch.sigmoid((prediction[:,:, 5 : 5 + num_classes]))

    prediction[:,:,:4] *= stride
    
    return prediction

# %%
class EmptyLayer(nn.Module):
    def __init__(self):
        super(EmptyLayer, self).__init__()
        

class DetectionLayer(nn.Module):
    def __init__(self, anchors):
        super(DetectionLayer, self).__init__()
        self.anchors = anchors

# %%
def create_modules(blocks):
    net_info = blocks[0]     #Captures the information about the input and pre-processing    
    module_list = nn.ModuleList()
    prev_filters = 3
    output_filters = []
    
    for index, x in enumerate(blocks[1:]):
        module = nn.Sequential()
    
        #check the type of block
        #create a new module for the block
        #append to module_list
        
        #If it's a convolutional layer
        if (x["type"] == "convolutional"):
            #Get the info about the layer
            activation = x["activation"]
            try:
                batch_normalize = int(x["batch_normalize"])
                bias = False
            except:
                batch_normalize = 0
                bias = True
        
            filters= int(x["filters"])
            padding = int(x["pad"])
            kernel_size = int(x["size"])
            stride = int(x["stride"])
        
            if padding:
                pad = (kernel_size - 1) // 2
            else:
                pad = 0
        
            #Add the convolutional layer
            conv = nn.Conv2d(prev_filters, filters, kernel_size, stride, pad, bias = bias)
            module.add_module("conv_{0}".format(index), conv)
        
            #Add the Batch Norm Layer
            if batch_normalize:
                bn = nn.BatchNorm2d(filters)
                module.add_module("batch_norm_{0}".format(index), bn)
        
            #Check the activation. 
            #It is either Linear or a Leaky ReLU for YOLO
            if activation == "leaky":
                activn = nn.LeakyReLU(0.1, inplace = True)
                module.add_module("leaky_{0}".format(index), activn)
        
            #If it's an upsampling layer
            #We use Bilinear2dUpsampling
        elif (x["type"] == "upsample"):
            stride = int(x["stride"])
            upsample = nn.Upsample(scale_factor = 2, mode = "nearest")
            module.add_module("upsample_{}".format(index), upsample)
                
        #If it is a route layer
        elif (x["type"] == "route"):
            x["layers"] = x["layers"].split(',')
            #Start  of a route
            start = int(x["layers"][0])
            #end, if there exists one.
            try:
                end = int(x["layers"][1])
            except:
                end = 0
            #Positive anotation
            if start > 0: 
                start = start - index
            if end > 0:
                end = end - index
            route = EmptyLayer()
            module.add_module("route_{0}".format(index), route)
            if end < 0:
                filters = output_filters[index + start] + output_filters[index + end]
            else:
                filters= output_filters[index + start]
    
        #shortcut corresponds to skip connection
        elif x["type"] == "shortcut":
            shortcut = EmptyLayer()
            module.add_module("shortcut_{}".format(index), shortcut)
            
        #Yolo is the detection layer
        elif x["type"] == "yolo":
            mask = x["mask"].split(",")
            mask = [int(x) for x in mask]
    
            anchors = x["anchors"].split(",")
            anchors = [int(a) for a in anchors]
            anchors = [(anchors[i], anchors[i+1]) for i in range(0, len(anchors),2)]
            anchors = [anchors[i] for i in mask]
    
            detection = DetectionLayer(anchors)
            module.add_module("Detection_{}".format(index), detection)
                              
        module_list.append(module)
        prev_filters = filters
        output_filters.append(filters)
    return (net_info, module_list)

# %%
class Darknet(nn.Module):
    def __init__(self, cfgfile):
        super(Darknet, self).__init__()
        self.blocks = parse_cfg(cfgfile)
        self.net_info, self.module_list = create_modules(self.blocks)
        
    def forward(self, x, CUDA):
        modules = self.blocks[1:]
        outputs = {}   #We cache the outputs for the route layer
        
        write = 0
        for i, module in enumerate(modules):        
            module_type = (module["type"])
            
            if module_type == "convolutional" or module_type == "upsample":
                x = self.module_list[i](x)
    
            elif module_type == "route":
                layers = module["layers"]
                layers = [int(a) for a in layers]
    
                if (layers[0]) > 0:
                    layers[0] = layers[0] - i
    
                if len(layers) == 1:
                    x = outputs[i + (layers[0])]
    
                else:
                    if (layers[1]) > 0:
                        layers[1] = layers[1] - i
    
                    map1 = outputs[i + layers[0]]
                    map2 = outputs[i + layers[1]]
                    x = torch.cat((map1, map2), 1)
                
    
            elif  module_type == "shortcut":
                from_ = int(module["from"])
                x = outputs[i-1] + outputs[i+from_]
    
            elif module_type == 'yolo':        
                anchors = self.module_list[i][0].anchors
                #Get the input dimensions
                inp_dim = int (self.net_info["height"])
        
                #Get the number of classes
                num_classes = int (module["classes"])
        
                #Transform 
                x = x.data
                x = predict_transform(x, inp_dim, anchors, num_classes, CUDA)
                if not write:              #if no collector has been intialised. 
                    detections = x
                    write = 1
        
                else:       
                    detections = torch.cat((detections, x), 1)
        
            outputs[i] = x
        
        return detections
    def load_weights(self , weightfile):
        fp = open(weightfile , "rb")
        header = np.fromfile(fp , dtype = np.int32 , count = 5)
        self.header = torch.tensor(header)
        self.seen = self.header[3]
        weights = np.fromfile(fp , dtype = np.float32)
        ptr = 0
        for i in range(len(self.module_list)):
            module_type = self.blocks[i + 1]["type"]
            if(module_type == "convolutional"):
                model = self.module_list[i]
                try:
                    batch_normalize = int(self.blocks[i + 1]["batch_normalize"])
                except:
                    batch_normalize = 0
                conv = model[0]
                if (batch_normalize):
                    bn = model[1]

                    #Get the number of weights of Batch Norm Layer
                    num_bn_biases = bn.bias.numel()

                    #Load the weights
                    bn_biases = torch.from_numpy(weights[ptr:ptr + num_bn_biases])
                    ptr += num_bn_biases

                    bn_weights = torch.from_numpy(weights[ptr: ptr + num_bn_biases])
                    ptr  += num_bn_biases

                    bn_running_mean = torch.from_numpy(weights[ptr: ptr + num_bn_biases])
                    ptr  += num_bn_biases

                    bn_running_var = torch.from_numpy(weights[ptr: ptr + num_bn_biases])
                    ptr  += num_bn_biases

                    #Cast the loaded weights into dims of model weights. 
                    bn_biases = bn_biases.view_as(bn.bias.data)
                    bn_weights = bn_weights.view_as(bn.weight.data)
                    bn_running_mean = bn_running_mean.view_as(bn.running_mean)
                    bn_running_var = bn_running_var.view_as(bn.running_var)

                    #Copy the data to model
                    bn.bias.data.copy_(bn_biases)
                    bn.weight.data.copy_(bn_weights)
                    bn.running_mean.copy_(bn_running_mean)
                    bn.running_var.copy_(bn_running_var)

                else:
                    num_biases = conv.bias.numel()

                    #Load the weights
                    conv_biases = torch.tensor(weights[ptr: ptr + num_biases])
                    ptr = ptr + num_biases
                    #reshape the loaded weights according to the dims of the model weights
                    conv_biases = conv_biases.view_as(conv.bias.data)
                    #Finally copy the data
                    conv.bias.data.copy_(conv_biases)

                #Let us load the weights for the Convolutional layers
                num_weights = conv.weight.numel()

                #Do the same as above for weights
                conv_weights = torch.from_numpy(weights[ptr:ptr+num_weights])
                ptr = ptr + num_weights

                conv_weights = conv_weights.view_as(conv.weight.data)
                conv.weight.data.copy_(conv_weights)

# %%
def get_test_input():
    img = cv2.imread("dog-cycle-car.png")
    img = cv2.resize(img, (416,416))          #Resize to the input dimension
    img_ =  img[:,:,::-1].transpose((2,0,1))  # BGR -> RGB | H X W C -> C X H X W 
    img_ = img_[np.newaxis,:,:,:]/255.0       #Add a channel at 0 (for batch) | Normalise
    img_ = torch.tensor(img_.astype(np.float32))                    # Convert to Variable
    return img_

# %%
model = Darknet("drive/My Drive/yolov3/cfg/yolov3.cfg")
model.load_weights("drive/My Drive/yolov3/yolov3.weights")

# %%
def unique(tensor):
    tensor_np = tensor.cpu().numpy()
    unique_np = np.unique(tensor_np)
    unique_tensor = torch.tensor(unique_np)
    tensor_res = tensor.new(unique_tensor.shape)
    tensor_res.copy_(unique_tensor)
    return tensor_res

# %%
def bbox_iou(box1 , box2):
    b1_x1, b1_y1, b1_x2, b1_y2 = box1[:,0], box1[:,1], box1[:,2], box1[:,3]
    b2_x1, b2_y1, b2_x2, b2_y2 = box2[:,0], box2[:,1], box2[:,2], box2[:,3]
    
    inter_rect_x1 =  torch.max(b1_x1, b2_x1)
    inter_rect_y1 =  torch.max(b1_y1, b2_y1)
    inter_rect_x2 =  torch.min(b1_x2, b2_x2)
    inter_rect_y2 =  torch.min(b1_y2, b2_y2)
    inter_area = torch.clamp(inter_rect_x2 - inter_rect_x1 + 1, min=0) * torch.clamp(inter_rect_y2 - inter_rect_y1 + 1, min=0)
    #Union Area
    b1_area = (b1_x2 - b1_x1 + 1)*(b1_y2 - b1_y1 + 1)
    b2_area = (b2_x2 - b2_x1 + 1)*(b2_y2 - b2_y1 + 1)
    
    iou = inter_area / (b1_area + b2_area - inter_area)
    return iou

# %%
def write_results(prediction , confidence , num_classes , nms_conf = .4):
    conf_mask = (prediction[: , : , 4] > confidence).float().unsqueeze(2)
    prediction = prediction*conf_mask
    box_corner = prediction.new(prediction.shape)
    box_corner[:,:,0] = (prediction[:,:,0] - prediction[:,:,2]/2)
    box_corner[:,:,1] = (prediction[:,:,1] - prediction[:,:,3]/2)
    box_corner[:,:,2] = (prediction[:,:,0] + prediction[:,:,2]/2) 
    box_corner[:,:,3] = (prediction[:,:,1] + prediction[:,:,3]/2)
    prediction[:,:,:4] = box_corner[:,:,:4]
    batch_size = prediction.size(0)
    write = False
    for ind in range(batch_size):
        image_pred = prediction[ind]
        max_conf , max_conf_score  = torch.max(image_pred[: , 5:5 + num_classes] , 1)
        max_conf = max_conf.float().unsqueeze(1)
        max_conf_score = max_conf_score.float().unsqueeze(1)
        seq = (image_pred[:,:5] , max_conf , max_conf_score)
        image_pred = torch.cat(seq , 1)
        non_zero_ind = (torch.nonzero(image_pred[:,4]))
        try:
            image_pred_ = image_pred[non_zero_ind.squeeze() , :].view(-1,7)
        except:
            continue
        if(image_pred_.shape[0] == 0):
            continue
        img_classes = unique(image_pred_[:,-1])
        for cls in img_classes:
            cls_mask = image_pred_*(image_pred_[:,-1] == cls).float().unsqueeze(1)
            class_mask_ind = torch.nonzero(cls_mask[:,-2]).squeeze()
            image_pred_class = image_pred_[class_mask_ind].view(-1, 7)
            
            conf_sort_index = torch.sort(image_pred_class[:,4] , descending = True)[1]
            image_pred_class  =image_pred_class[conf_sort_index]
            idx  =image_pred_class.size(0)
            for i in range(idx):
                try:
                    ious = bbox_iou(image_pred_class[i].unsqueeze(0), image_pred_class[i+1:])
                except ValueError:
                    break
                except IndexError:
                    break
                iou_mask = (ious < nms_conf).float().unsqueeze(1)
                image_pred_class[i+1:] = image_pred_class[i+1:]*iou_mask
                non_zero_ind  = torch.nonzero(image_pred_class[: , 4])
                image_pred_class = image_pred_class[non_zero_ind].view(-1,7)
            batch_ind = image_pred_class.new(image_pred_class.size(0), 1).fill_(ind) 
            seq = batch_ind, image_pred_class
            if not write:
                output = torch.cat(seq , 1)
                write = True
            else:
                out = torch.cat(seq,1)
                output  = torch.cat((output,out))
                
    try:
        return output
    except:
        return 0

# %%
def load_classes(namesfile):
    fp = open(namesfile, "r")
    names = fp.read().split("\n")[:-1]
    return names

# %%
num_classes = 80    #For COCO
classes = load_classes("drive/My Drive/common/coco.names")

# %%
model.to(device)
model.eval()

# %%
def preprocess_frame(image, target_height=224, target_width=224):
    if len(image.shape) == 2:
        image = np.tile(image[:,:,None], 3)
    elif len(image.shape) == 4:
        image = image[:,:,:,0]

    image = skimage.img_as_float(image).astype(np.float32)
    height, width, rgb = image.shape
    if width == height:
        resized_image = cv2.resize(image, (target_height,target_width))

    elif height < width:
        resized_image = cv2.resize(image, (int(width * float(target_height)/height), target_width))
        cropping_length = int((resized_image.shape[1] - target_height) / 2)
        resized_image = resized_image[:,cropping_length:resized_image.shape[1] - cropping_length]

    else:
        resized_image = cv2.resize(image, (target_height, int(height * float(target_width) / width)))
        cropping_length = int((resized_image.shape[0] - target_width) / 2)
        resized_image = resized_image[cropping_length:resized_image.shape[0] - cropping_length,:]

    return cv2.resize(resized_image, (target_height, target_width))

# %%
vgg16 = models.vgg16(pretrained=True)
vgg16.classifier = nn.Sequential(*[vgg16.classifier[i] for i in range(4)])

#temp = 1
resnet152 = models.resnet152(pretrained=True)
modules=list(resnet152.children())[:-1]
resnet152 = nn.Sequential(*modules)
for p in resnet152.parameters():
    p.requires_grad = False
for p in vgg16.parameters():
    p.requires_grad = False
resnet152 = resnet152.to(device)
vgg16 = vgg16.to(device).eval()
num_frames = 80
dim_embedding = 300
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/checkpoints/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:08<00:00, 65262157.65it/s]
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to /root/.cache/torch/checkpoints/resnet152-b121ed2d.pth
# 100%|██████████| 241530880/241530880 [00:06<00:00, 38864936.35it/s]

# %%
video_path = "drive/My Drive/common/clips"

# %%
video_save_vgg = "drive/My Drive/common/cnn_features"
video_save_res = "drive/My Drive/common/res_features"
video_save_yolo = "drive/My Drive/common/object_features"

# %%
data_path = "drive/My Drive/yolov3/data"
wordtoindex_path = "drive/My Drive/common/wordtoindex.pickle"
embedding_path = "drive/My Drive/common/embedding.npy"

# %%
def save_dict(path , dct):
    with open(path , "wb") as handle:
        pickle.dump(dct , handle , protocol = pickle.HIGHEST_PROTOCOL)
def load_dict(path):
    with open(path, "rb") as handle:
        b = pickle.load(handle)
    return b

# %%
embedding = np.load(embedding_path).astype(np.float32)
wordtoindex = load_dict(wordtoindex_path)

# %%
def convert_names(name):
  if(name == 'traffic light'):
    return "traffic"
  elif(name == "fire hydrant"):
    return "extinguisher"
  elif(name == "stop sign"):
    return "signboard"
  elif(name == "parking meter"):
    return "meter"
  elif(name == "sports ball"):
    return "ball"
  elif(name == "baseball bat"):
    return "bat"
  elif(name == "pottedplant"):
    return "plant"
  elif(name == "baseball glove"):
    return "glove"
  elif(name == "tennis racket"):
    return "racket"
  elif(name == "wine glass"):
    return "glass"
  elif(name == "hot dog"):
    return "food"
  elif(name == "diningtable"):
    return "table"
  elif(name == "tvmonitor"):
    return "tv"
  elif(name ==  'cell phone'):
    return "phone"
  elif(name == "teddy bear"):
    return "toy"
  elif(name == "hair drier"):
    return "drier"
  elif(name == "aeroplane"):
    return "plane" 
  else:
    return name

# %%
for w in classes:
    if(convert_names(w) not in wordtoindex):
        print(w)

# %%
vids  = os.listdir(video_path)
vids = filter(lambda x : x.endswith('avi') , vids)
video_number = 1
for vid in vids:
    object_less = 0
    path = os.path.join(video_path , vid)
    yolo_save_path = os.path.join(video_save_yolo , vid + ".npy")
    vgg_save_path = os.path.join(video_save_vgg , vid + ".npy")
    res_save_path = os.path.join(video_save_res , vid + ".npy")
    if(os.path.exists(vgg_save_path) and os.path.exists(yolo_save_path) and os.path.exists(res_save_path)):
        print("already processes")
        video_number = video_number + 1
        continue
        
#    if(os.path.exists(os.path.join(video_save_yolo , ".npy"))):
#        print("already processed")
#        continue
    cap = cv2.VideoCapture(path)
    frame_count = 0
    frame_list = []
    while True:
        ret , frame = cap.read()
        if(ret == False):
            break
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame_list.append(frame)
        frame_count = frame_count + 1
    frame_list = np.array(frame_list)
    if frame_count > 80:
        frame_indices = np.linspace(0, frame_count, num=num_frames, endpoint=False).astype(int)
        frame_list = frame_list[frame_indices]
    cropped_array = []
    for i in range(frame_list.shape[0]):
        cropped_array.append(preprocess_frame(frame_list[i]).transpose(2,0,1))
    vgg_tensor = torch.tensor(cropped_array).to(device)
    yolo_tensor  = torch.tensor(cropped_array).to(device)
    norm = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    
    for i in range(vgg_tensor.size(0)):
        vgg_tensor[i] = norm(vgg_tensor[i])
    object_list = np.zeros((yolo_tensor.size(0) , dim_embedding))
    for yolo_frame in range(yolo_tensor.size(0)):
        inp = yolo_tensor[yolo_frame:yolo_frame+1]
        pred = model(inp , True)
        res = write_results(pred , .65 ,80 )
      
        if(type(res) is int):
            object_less = object_less + 1
        else:
            _, index = torch.sort(res[: , 5] , 0 , descending = True)
            res = res[index][0].to("cpu").numpy()
            class_index = int(res[-1].item())
            obj  = classes[class_index]
            object_list[yolo_frame] = embedding[wordtoindex[convert_names(obj)]] 
    
    np.save(yolo_save_path , object_list)
    vgg_features  = vgg16(vgg_tensor).detach().to("cpu").numpy()
    res_features  = resnet152(vgg_tensor).squeeze().detach().to("cpu").numpy()
    np.save(res_save_path , res_features)
    np.save(vgg_save_path , vgg_features)
    
    
    print("done video number " , video_number)
    print("objectless frames = " , object_less)
    video_number = video_number + 1
# Out:
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# already processes
# done video number  1507
# objectless frames =  0
# done video number  1508
# objectless frames =  3
# done video number  1509
# objectless frames =  0
# done video number  1510
# objectless frames =  0
# done video number  1511
# objectless frames =  0
# done video number  1512
# objectless frames =  0
# done video number  1513
# objectless frames =  0
# done video number  1514
# objectless frames =  0
# done video number  1515
# objectless frames =  46
# done video number  1516
# objectless frames =  77
# done video number  1517
# objectless frames =  0
# done video number  1518
# objectless frames =  0
# done video number  1519
# objectless frames =  0
# done video number  1520
# objectless frames =  25
# done video number  1521
# objectless frames =  6
# done video number  1522
# objectless frames =  0
# done video number  1523
# objectless frames =  0
# done video number  1524
# objectless frames =  0
# done video number  1525
# objectless frames =  23
# done video number  1526
# objectless frames =  6
# done video number  1527
# objectless frames =  0
# done video number  1528
# objectless frames =  8
# done video number  1529
# objectless frames =  5
# done video number  1530
# objectless frames =  5
# done video number  1531
# objectless frames =  59
# done video number  1532
# objectless frames =  1
# done video number  1533
# objectless frames =  32
# done video number  1534
# objectless frames =  5
# done video number  1535
# objectless frames =  2
# done video number  1536
# objectless frames =  0
# done video number  1537
# objectless frames =  0
# done video number  1538
# objectless frames =  1
# done video number  1539
# objectless frames =  0
# done video number  1540
# objectless frames =  52
# done video number  1541
# objectless frames =  54
# done video number  1542
# objectless frames =  0
# done video number  1543
# objectless frames =  38
# done video number  1544
# objectless frames =  0
# done video number  1545
# objectless frames =  5
# done video number  1546
# objectless frames =  35
# done video number  1547
# objectless frames =  0
# done video number  1548
# objectless frames =  31
# done video number  1549
# objectless frames =  0
# done video number  1550
# objectless frames =  25
# done video number  1551
# objectless frames =  0
# done video number  1552
# objectless frames =  41
# done video number  1553
# objectless frames =  1
# done video number  1554
# objectless frames =  0
# done video number  1555
# objectless frames =  0
# done video number  1556
# objectless frames =  2
# done video number  1557
# objectless frames =  2
# done video number  1558
# objectless frames =  0
# done video number  1559
# objectless frames =  74
# done video number  1560
# objectless frames =  6
# done video number  1561
# objectless frames =  6
# done video number  1562
# objectless frames =  0
# done video number  1563
# objectless frames =  0
# done video number  1564
# objectless frames =  0
# done video number  1565
# objectless frames =  7
# done video number  1566
# objectless frames =  6
# done video number  1567
# objectless frames =  1
# done video number  1568
# objectless frames =  12
# done video number  1569
# objectless frames =  0
# done video number  1570
# objectless frames =  0
# done video number  1571
# objectless frames =  0
# done video number  1572
# objectless frames =  20
# done video number  1573
# objectless frames =  79
# done video number  1574
# objectless frames =  15
# done video number  1575
# objectless frames =  0
# done video number  1576
# objectless frames =  22
# done video number  1577
# objectless frames =  0
# done video number  1578
# objectless frames =  0
# done video number  1579
# objectless frames =  0
# done video number  1580
# objectless frames =  4
# done video number  1581
# objectless frames =  28
# done video number  1582
# objectless frames =  0
# done video number  1583
# objectless frames =  0
# done video number  1584
# objectless frames =  4
# done video number  1585
# objectless frames =  28
# done video number  1586
# objectless frames =  54
# done video number  1587
# objectless frames =  19
# done video number  1588
# objectless frames =  57
# done video number  1589
# objectless frames =  12
# done video number  1590
# objectless frames =  80
# done video number  1591
# objectless frames =  0
# done video number  1592
# objectless frames =  10
# done video number  1593
# objectless frames =  0
# done video number  1594
# objectless frames =  0
# done video number  1595
# objectless frames =  12
# done video number  1596
# objectless frames =  1
# done video number  1597
# objectless frames =  18
# done video number  1598
# objectless frames =  11
# done video number  1599
# objectless frames =  0
# done video number  1600
# objectless frames =  3
# done video number  1601
# objectless frames =  0
# done video number  1602
# objectless frames =  10
# done video number  1603
# objectless frames =  0
# done video number  1604
# objectless frames =  0
# done video number  1605
# objectless frames =  47
# done video number  1606
# objectless frames =  2
# done video number  1607
# objectless frames =  80
# done video number  1608
# objectless frames =  14
# done video number  1609
# objectless frames =  0
# done video number  1610
# objectless frames =  7
# done video number  1611
# objectless frames =  30
# done video number  1612
# objectless frames =  0
# done video number  1613
# objectless frames =  0
# done video number  1614
# objectless frames =  0
# done video number  1615
# objectless frames =  23
# done video number  1616
# objectless frames =  56
# done video number  1617
# objectless frames =  18
# done video number  1618
# objectless frames =  0
# done video number  1619
# objectless frames =  0
# done video number  1620
# objectless frames =  0
# done video number  1621
# objectless frames =  13
# done video number  1622
# objectless frames =  5
# done video number  1623
# objectless frames =  0
# done video number  1624
# objectless frames =  0
# done video number  1625
# objectless frames =  46
# done video number  1626
# objectless frames =  6
# done video number  1627
# objectless frames =  23
# done video number  1628
# objectless frames =  15
# done video number  1629
# objectless frames =  0
# done video number  1630
# objectless frames =  1
# done video number  1631
# objectless frames =  10
# done video number  1632
# objectless frames =  0
# done video number  1633
# objectless frames =  2
# done video number  1634
# objectless frames =  0
# done video number  1635
# objectless frames =  0
# done video number  1636
# objectless frames =  2
# done video number  1637
# objectless frames =  0
# done video number  1638
# objectless frames =  0
# done video number  1639
# objectless frames =  0
# done video number  1640
# objectless frames =  1
# done video number  1641
# objectless frames =  17
# done video number  1642
# objectless frames =  2
# done video number  1643
# objectless frames =  14
# done video number  1644
# objectless frames =  16
# done video number  1645
# objectless frames =  57
# done video number  1646
# objectless frames =  0
# done video number  1647
# objectless frames =  22
# done video number  1648
# objectless frames =  58
# done video number  1649
# objectless frames =  0
# done video number  1650
# objectless frames =  17
# done video number  1651
# objectless frames =  12
# done video number  1652
# objectless frames =  14
# done video number  1653
# objectless frames =  16
# done video number  1654
# objectless frames =  26
# done video number  1655
# objectless frames =  15
# done video number  1656
# objectless frames =  30
# done video number  1657
# objectless frames =  11
# done video number  1658
# objectless frames =  20
# done video number  1659
# objectless frames =  18
# done video number  1660
# objectless frames =  0
# done video number  1661
# objectless frames =  0
# done video number  1662
# objectless frames =  52
# done video number  1663
# objectless frames =  43
# done video number  1664
# objectless frames =  1
# done video number  1665
# objectless frames =  25
# done video number  1666
# objectless frames =  20
# done video number  1667
# objectless frames =  67
# done video number  1668
# objectless frames =  0
# done video number  1669
# objectless frames =  0
# done video number  1670
# objectless frames =  1
# done video number  1671
# objectless frames =  14
# done video number  1672
# objectless frames =  0
# done video number  1673
# objectless frames =  0
# done video number  1674
# objectless frames =  26
# done video number  1675
# objectless frames =  0
# done video number  1676
# objectless frames =  0
# done video number  1677
# objectless frames =  2
# done video number  1678
# objectless frames =  0
# done video number  1679
# objectless frames =  80
# done video number  1680
# objectless frames =  56
# done video number  1681
# objectless frames =  0
# done video number  1682
# objectless frames =  6
# done video number  1683
# objectless frames =  2
# done video number  1684
# objectless frames =  13
# done video number  1685
# objectless frames =  23
# done video number  1686
# objectless frames =  75
# done video number  1687
# objectless frames =  11
# done video number  1688
# objectless frames =  69
# done video number  1689
# objectless frames =  1
# done video number  1690
# objectless frames =  80
# done video number  1691
# objectless frames =  37
# done video number  1692
# objectless frames =  44
# done video number  1693
# objectless frames =  12
# done video number  1694
# objectless frames =  38
# done video number  1695
# objectless frames =  0
# done video number  1696
# objectless frames =  9
# done video number  1697
# objectless frames =  0
# done video number  1698
# objectless frames =  1
# done video number  1699
# objectless frames =  42
# done video number  1700
# objectless frames =  0
# done video number  1701
# objectless frames =  0
# done video number  1702
# objectless frames =  53
# done video number  1703
# objectless frames =  1
# done video number  1704
# objectless frames =  7
# done video number  1705
# objectless frames =  13
# done video number  1706
# objectless frames =  9
# done video number  1707
# objectless frames =  6
# done video number  1708
# objectless frames =  23
# done video number  1709
# objectless frames =  18
# done video number  1710
# objectless frames =  32
# done video number  1711
# objectless frames =  0
# done video number  1712
# objectless frames =  14
# done video number  1713
# objectless frames =  20
# done video number  1714
# objectless frames =  36
# done video number  1715
# objectless frames =  49
# done video number  1716
# objectless frames =  0
# done video number  1717
# objectless frames =  26
# done video number  1718
# objectless frames =  9
# done video number  1719
# objectless frames =  0
# done video number  1720
# objectless frames =  0
# done video number  1721
# objectless frames =  1
# done video number  1722
# objectless frames =  8
# done video number  1723
# objectless frames =  1
# done video number  1724
# objectless frames =  41
# done video number  1725
# objectless frames =  15
# done video number  1726
# objectless frames =  36
# done video number  1727
# objectless frames =  0
# done video number  1728
# objectless frames =  0
# done video number  1729
# objectless frames =  33
# done video number  1730
# objectless frames =  28
# done video number  1731
# objectless frames =  33
# done video number  1732
# objectless frames =  8
# done video number  1733
# objectless frames =  1
# done video number  1734
# objectless frames =  13
# done video number  1735
# objectless frames =  0
# done video number  1736
# objectless frames =  42
# done video number  1737
# objectless frames =  0
# done video number  1738
# objectless frames =  28
# done video number  1739
# objectless frames =  0
# done video number  1740
# objectless frames =  7
# done video number  1741
# objectless frames =  11
# done video number  1742
# objectless frames =  21
# done video number  1743
# objectless frames =  3
# done video number  1744
# objectless frames =  0
# done video number  1745
# objectless frames =  34
# done video number  1746
# objectless frames =  0
# done video number  1747
# objectless frames =  2
# done video number  1748
# objectless frames =  0
# done video number  1749
# objectless frames =  4
# done video number  1750
# objectless frames =  31
# done video number  1751
# objectless frames =  0
# done video number  1752
# objectless frames =  19
# done video number  1753
# objectless frames =  14
# done video number  1754
# objectless frames =  0
# done video number  1755
# objectless frames =  11
# done video number  1756
# objectless frames =  3
# done video number  1757
# objectless frames =  7
# done video number  1758
# objectless frames =  20
# done video number  1759
# objectless frames =  0
# done video number  1760
# objectless frames =  1
# done video number  1761
# objectless frames =  0
# done video number  1762
# objectless frames =  0
# done video number  1763
# objectless frames =  0
# done video number  1764
# objectless frames =  1
# done video number  1765
# objectless frames =  10
# done video number  1766
# objectless frames =  0
# done video number  1767
# objectless frames =  0
# done video number  1768
# objectless frames =  9
# done video number  1769
# objectless frames =  22
# done video number  1770
# objectless frames =  10
# done video number  1771
# objectless frames =  0
# done video number  1772
# objectless frames =  5
# done video number  1773
# objectless frames =  0
# done video number  1774
# objectless frames =  0
# done video number  1775
# objectless frames =  71
# done video number  1776
# objectless frames =  25
# done video number  1777
# objectless frames =  4
# done video number  1778
# objectless frames =  79
# done video number  1779
# objectless frames =  8
# done video number  1780
# objectless frames =  0
# done video number  1781
# objectless frames =  1
# done video number  1782
# objectless frames =  6
# done video number  1783
# objectless frames =  2
# done video number  1784
# objectless frames =  14
# done video number  1785
# objectless frames =  46
# done video number  1786
# objectless frames =  15
# done video number  1787
# objectless frames =  8
# done video number  1788
# objectless frames =  2
# done video number  1789
# objectless frames =  0
# done video number  1790
# objectless frames =  6
# done video number  1791
# objectless frames =  28
# done video number  1792
# objectless frames =  0
# done video number  1793
# objectless frames =  10
# done video number  1794
# objectless frames =  60
# done video number  1795
# objectless frames =  0
# done video number  1796
# objectless frames =  5
# done video number  1797
# objectless frames =  4
# done video number  1798
# objectless frames =  0
# done video number  1799
# objectless frames =  14
# done video number  1800
# objectless frames =  0
# done video number  1801
# objectless frames =  8
# done video number  1802
# objectless frames =  22
# done video number  1803
# objectless frames =  9
# done video number  1804
# objectless frames =  62
# done video number  1805
# objectless frames =  0
# done video number  1806
# objectless frames =  0
# done video number  1807
# objectless frames =  48
# done video number  1808
# objectless frames =  53
# done video number  1809
# objectless frames =  0
# done video number  1810
# objectless frames =  0
# done video number  1811
# objectless frames =  0
# done video number  1812
# objectless frames =  18
# done video number  1813
# objectless frames =  9
# done video number  1814
# objectless frames =  31
# done video number  1815
# objectless frames =  21
# done video number  1816
# objectless frames =  0
# done video number  1817
# objectless frames =  10
# done video number  1818
# objectless frames =  0
# done video number  1819
# objectless frames =  1
# done video number  1820
# objectless frames =  18
# done video number  1821
# objectless frames =  29
# done video number  1822
# objectless frames =  23
# done video number  1823
# objectless frames =  28
# done video number  1824
# objectless frames =  0
# done video number  1825
# objectless frames =  6
# done video number  1826
# objectless frames =  34
# done video number  1827
# objectless frames =  0
# done video number  1828
# objectless frames =  34
# done video number  1829
# objectless frames =  0
# done video number  1830
# objectless frames =  0
# done video number  1831
# objectless frames =  0
# done video number  1832
# objectless frames =  0
# done video number  1833
# objectless frames =  2
# done video number  1834
# objectless frames =  31
# done video number  1835
# objectless frames =  2
# done video number  1836
# objectless frames =  61
# done video number  1837
# objectless frames =  15
# done video number  1838
# objectless frames =  1
# done video number  1839
# objectless frames =  14
# done video number  1840
# objectless frames =  34
# done video number  1841
# objectless frames =  0
# done video number  1842
# objectless frames =  0
# done video number  1843
# objectless frames =  28
# done video number  1844
# objectless frames =  5
# done video number  1845
# objectless frames =  5
# done video number  1846
# objectless frames =  26
# done video number  1847
# objectless frames =  19
# done video number  1848
# objectless frames =  78
# done video number  1849
# objectless frames =  1
# done video number  1850
# objectless frames =  0
# done video number  1851
# objectless frames =  3
# done video number  1852
# objectless frames =  42
# done video number  1853
# objectless frames =  37
# done video number  1854
# objectless frames =  26
# done video number  1855
# objectless frames =  44
# done video number  1856
# objectless frames =  0
# done video number  1857
# objectless frames =  2
# done video number  1858
# objectless frames =  8
# done video number  1859
# objectless frames =  1
# done video number  1860
# objectless frames =  71
# done video number  1861
# objectless frames =  1
# done video number  1862
# objectless frames =  21
# done video number  1863
# objectless frames =  15
# done video number  1864
# objectless frames =  18
# done video number  1865
# objectless frames =  9
# done video number  1866
# objectless frames =  10
# done video number  1867
# objectless frames =  1
# done video number  1868
# objectless frames =  30
# done video number  1869
# objectless frames =  3
# done video number  1870
# objectless frames =  0
# done video number  1871
# objectless frames =  5
# done video number  1872
# objectless frames =  0
# done video number  1873
# objectless frames =  5
# done video number  1874
# objectless frames =  0
# done video number  1875
# objectless frames =  55
# done video number  1876
# objectless frames =  0
# done video number  1877
# objectless frames =  0
# done video number  1878
# objectless frames =  14
# done video number  1879
# objectless frames =  57
# done video number  1880
# objectless frames =  18
# done video number  1881
# objectless frames =  0
# done video number  1882
# objectless frames =  0
# done video number  1883
# objectless frames =  31
# done video number  1884
# objectless frames =  0
# done video number  1885
# objectless frames =  35
# done video number  1886
# objectless frames =  7
# done video number  1887
# objectless frames =  0
# done video number  1888
# objectless frames =  0
# done video number  1889
# objectless frames =  0
# done video number  1890
# objectless frames =  0
# done video number  1891
# objectless frames =  0
# done video number  1892
# objectless frames =  30
# done video number  1893
# objectless frames =  4
# done video number  1894
# objectless frames =  0
# done video number  1895
# objectless frames =  15
# done video number  1896
# objectless frames =  10
# done video number  1897
# objectless frames =  0
# done video number  1898
# objectless frames =  60
# done video number  1899
# objectless frames =  15
# done video number  1900
# objectless frames =  1
# done video number  1901
# objectless frames =  12
# done video number  1902
# objectless frames =  0
# done video number  1903
# objectless frames =  0
# done video number  1904
# objectless frames =  0
# done video number  1905
# objectless frames =  15
# done video number  1906
# objectless frames =  0
# done video number  1907
# objectless frames =  23
# done video number  1908
# objectless frames =  0
# done video number  1909
# objectless frames =  5
# done video number  1910
# objectless frames =  13
# done video number  1911
# objectless frames =  4
# done video number  1912
# objectless frames =  0
# done video number  1913
# objectless frames =  0
# done video number  1914
# objectless frames =  0
# done video number  1915
# objectless frames =  22
# done video number  1916
# objectless frames =  3
# done video number  1917
# objectless frames =  61
# done video number  1918
# objectless frames =  5
# done video number  1919
# objectless frames =  1
# done video number  1920
# objectless frames =  0
# done video number  1921
# objectless frames =  54
# done video number  1922
# objectless frames =  9
# done video number  1923
# objectless frames =  46
# done video number  1924
# objectless frames =  0
# done video number  1925
# objectless frames =  50
# done video number  1926
# objectless frames =  43
# done video number  1927
# objectless frames =  6
# done video number  1928
# objectless frames =  80
# done video number  1929
# objectless frames =  0
# done video number  1930
# objectless frames =  72
# done video number  1931
# objectless frames =  4
# done video number  1932
# objectless frames =  0
# done video number  1933
# objectless frames =  60
# done video number  1934
# objectless frames =  7
# done video number  1935
# objectless frames =  37
# done video number  1936
# objectless frames =  2
# done video number  1937
# objectless frames =  48
# done video number  1938
# objectless frames =  10
# done video number  1939
# objectless frames =  0
# done video number  1940
# objectless frames =  8
# done video number  1941
# objectless frames =  19
# done video number  1942
# objectless frames =  0
# done video number  1943
# objectless frames =  1
# done video number  1944
# objectless frames =  1
# done video number  1945
# objectless frames =  0
# done video number  1946
# objectless frames =  1
# done video number  1947
# objectless frames =  77
# done video number  1948
# objectless frames =  0
# done video number  1949
# objectless frames =  0
# done video number  1950
# objectless frames =  19
# done video number  1951
# objectless frames =  10
# done video number  1952
# objectless frames =  0
# done video number  1953
# objectless frames =  12
# done video number  1954
# objectless frames =  0
# done video number  1955
# objectless frames =  0
# done video number  1956
# objectless frames =  0
# done video number  1957
# objectless frames =  0
# done video number  1958
# objectless frames =  0
# done video number  1959
# objectless frames =  36
# done video number  1960
# objectless frames =  3
# done video number  1961
# objectless frames =  0
# done video number  1962
# objectless frames =  29
# done video number  1963
# objectless frames =  4
# done video number  1964
# objectless frames =  6
# done video number  1965
# objectless frames =  70
# done video number  1966
# objectless frames =  0
# done video number  1967
# objectless frames =  0
# done video number  1968
# objectless frames =  31
# done video number  1969
# objectless frames =  0
# done video number  1970
# objectless frames =  0
